# %% [markdown]
# <a href="https://colab.research.google.com/github/GigiQR99/CV-Class3-Streamlit/blob/main/Countours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/fenago/cv2
# Out:
# fatal: destination path 'cv2' already exists and is not an empty directory.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
print(cv2.__version__)
# Out:
# 4.12.0

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
matplotlib.rcParams['image.cmap'] = 'gray'

# %%
imagePath = '/content/cv2/Mod3/shapes.jpg'
# imagePath = "/content/drlee.jpeg"
image = cv2.imread(imagePath)
imageGray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(imageGray);

# %%
ret, thresh = cv2.threshold(imageGray, 200, 255, cv2.THRESH_BINARY_INV)
plt.imshow(thresh);

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
print("Number of contours found = {}".format(len(contours)))
print("\nHierarchy : \n{}".format(hierarchy))
# Out:
# Number of contours found = 81
#
# Hierarchy :
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [ 5  3 -1 -1]
#   [ 6  4 -1 -1]
#   [ 7  5 -1 -1]
#   [ 8  6 -1 -1]
#   [ 9  7 -1 -1]
#   [10  8 -1 -1]
#   [11  9 -1 -1]
#   [12 10 -1 -1]
#   [13 11 -1 -1]
#   [14 12 -1 -1]
#   [15 13 -1 -1]
#   [16 14 -1 -1]
#   [17 15 -1 -1]
#   [18 16 -1 -1]
#   [19 17 -1 -1]
#   [20 18 -1 -1]
#   [21 19 -1 -1]
#   [22 20 -1 -1]
#   [23 21 -1 -1]
#   [24 22 -1 -1]
#   [25 23 -1 -1]
#   [26 24 -1 -1]
#   [27 25 -1 -1]
#   [28 26 -1 -1]
#   [29 27 -1 -1]
#   [30 28 -1 -1]
#   [31 29 -1 -1]
#   [32 30 -1 -1]
#   [33 31 -1 -1]
#   [34 32 -1 -1]
#   [35 33 -1 -1]
#   [36 34 -1 -1]
#   [37 35 -1 -1]
#   [38 36 -1 -1]
#   [39 37 -1 -1]
#   [40 38 -1 -1]
#   [41 39 -1 -1]
#   [42 40 -1 -1]
#   [43 41 -1 -1]
#   [44 42 -1 -1]
#   [45 43 -1 -1]
#   [46 44 -1 -1]
#   [47 45 -1 -1]
#   [48 46 -1 -1]
#   [49 47 -1 -1]
#   [50 48 -1 -1]
#   [51 49 -1 -1]
#   [52 50 -1 -1]
#   [53 51 -1 -1]
#   [54 52 -1 -1]
#   [55 53 -1 -1]
#   [56 54 -1 -1]
#   [57 55 -1 -1]
#   [58 56 -1 -1]
#   [59 57 -1 -1]
#   [60 58 -1 -1]
#   [61 59 -1 -1]
#   [62 60 -1 -1]
#   [63 61 -1 -1]
#   [64 62 -1 -1]
#   [65 63 -1 -1]
#   [66 64 -1 -1]
#   [67 65 -1 -1]
#   [68 66 -1 -1]
#   [69 67 -1 -1]
#   [70 68 -1 -1]
#   [71 69 -1 -1]
#   [72 70 -1 -1]
#   [73 71 -1 -1]
#   [74 72 -1 -1]
#   [75 73 -1 -1]
#   [76 74 -1 -1]
#   [77 75 -1 -1]
#   [78 76 -1 -1]
#   [79 77 -1 -1]
#   [80 78 -1 -1]
#   [-1 79 -1 -1]]]

# %%
imageCopy1 = image.copy()
cv2.drawContours(imageCopy1, contours, -1, (0,0,255), 3)
plt.imshow(imageCopy1[:,:,::-1]);

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
print("Number of contours found = {}".format(len(contours)))
# Out:
# Number of contours found = 36

# %%
imageCopy2 = image.copy()
cv2.drawContours(imageCopy2, contours, -1, (0,0,255), 4)
plt.imshow(imageCopy2[:,:,::-1]);

# %%
imageCopy3 = image.copy()
cv2.drawContours(imageCopy3, contours[3], -1, (0,0,255), 4)
plt.imshow(imageCopy3[:,:,::-1]);

# %%
def convert_color(hsv):
    """Utility to convert a single hsv color tuple into bgr"""
    pixel_img = np.uint8([[hsv]])
    return tuple(int(i) for i in cv2.cvtColor(pixel_img, cv2.COLOR_HSV2BGR).flatten())
imageCopy4 = image.copy()
for i, single_contour in enumerate(contours):
    hsv = (int(i/len(contours) * 180), 255, 255)
    color = convert_color(hsv)
    cv2.drawContours(imageCopy4, contours, i, color, 3)
    plt.imshow(imageCopy4[:,:,::-1]);

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
imageCopy5 = image.copy()
cv2.drawContours(imageCopy5, contours, -1, (0,0,255), 3)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
imageCopy5 = image.copy()
cv2.drawContours(imageCopy5, contours, -1, (0,0,255), 3)
for cnt in contours:
    M = cv2.moments(cnt)
    x = int(round(M["m10"]/M["m00"]))
    y = int(round(M["m01"]/M["m00"]))
    cv2.circle(imageCopy5, (x,y), 10, (255,0,0), -1)
plt.imshow(imageCopy5[:,:,::-1]);

# %%
for index,cnt in enumerate(contours):
    area = cv2.contourArea(cnt)
    perimeter = cv2.arcLength(cnt, True)
    print("Contour #{} has area = {} and perimeter = {}".format(index+1,area,perimeter))
# Out:
# Contour #1 has area = 7.0 and perimeter = 9.656854152679443
# Contour #2 has area = 8.5 and perimeter = 11.071067690849304
# Contour #3 has area = 5.5 and perimeter = 9.071067690849304
# Contour #4 has area = 14.5 and perimeter = 15.071067690849304
# Contour #5 has area = 17.5 and perimeter = 15.899494767189026
# Contour #6 has area = 16.0 and perimeter = 15.656854152679443
# Contour #7 has area = 17.5 and perimeter = 15.899494767189026
# Contour #8 has area = 16.5 and perimeter = 15.899494767189026
# Contour #9 has area = 19.0 and perimeter = 16.485281229019165
# Contour #10 has area = 15.5 and perimeter = 15.899494767189026
# Contour #11 has area = 4.0 and perimeter = 7.656854152679443
# Contour #12 has area = 19.0 and perimeter = 16.485281229019165
# Contour #13 has area = 14.5 and perimeter = 15.071067690849304
# Contour #14 has area = 17.5 and perimeter = 15.899494767189026
# Contour #15 has area = 14.5 and perimeter = 15.071067690849304
# Contour #16 has area = 14.5 and perimeter = 15.071067690849304
# Contour #17 has area = 14.5 and perimeter = 15.071067690849304
# Contour #18 has area = 14.5 and perimeter = 15.071067690849304
# Contour #19 has area = 28.5 and perimeter = 21.071067690849304
# Contour #20 has area = 29.5 and perimeter = 21.071067690849304
# Contour #21 has area = 19.5 and perimeter = 54.38477599620819
# Contour #22 has area = 29.0 and perimeter = 20.485281229019165
# Contour #23 has area = 71.5 and perimeter = 64.04163002967834
# Contour #24 has area = 62.0 and perimeter = 38.97056233882904
# Contour #25 has area = 26.5 and perimeter = 21.899494767189026
# Contour #26 has area = 59.5 and perimeter = 40.3847758769989
# Contour #27 has area = 19.0 and perimeter = 25.656854152679443
# Contour #28 has area = 27.5 and perimeter = 21.071067690849304
# Contour #29 has area = 43.5 and perimeter = 42.38477599620819
# Contour #30 has area = 28.5 and perimeter = 21.071067690849304
# Contour #31 has area = 29.5 and perimeter = 21.071067690849304
# Contour #32 has area = 10.5 and perimeter = 28.727921843528748
# Contour #33 has area = 28.5 and perimeter = 21.071067690849304
# Contour #34 has area = 20.0 and perimeter = 17.313708305358887
# Contour #35 has area = 14.5 and perimeter = 15.071067690849304
# Contour #36 has area = 26.0 and perimeter = 19.656854152679443
# Contour #37 has area = 29.0 and perimeter = 21.656854152679443
# Contour #38 has area = 8.0 and perimeter = 30.14213514328003
# Contour #39 has area = 10.5 and perimeter = 24.242640614509583
# Contour #40 has area = 19.0 and perimeter = 17.313708305358887
# Contour #41 has area = 14.5 and perimeter = 15.071067690849304
# Contour #42 has area = 20.0 and perimeter = 17.313708305358887
# Contour #43 has area = 26.0 and perimeter = 19.656854152679443
# Contour #44 has area = 30.0 and perimeter = 21.656854152679443
# Contour #45 has area = 26.0 and perimeter = 19.656854152679443
# Contour #46 has area = 10.5 and perimeter = 24.242640614509583
# Contour #47 has area = 3192.0 and perimeter = 274.9949462413788
# Contour #48 has area = 4642.5 and perimeter = 709.0264735221863
# Contour #49 has area = 8.0 and perimeter = 11.313708305358887
# Contour #50 has area = 14.5 and perimeter = 15.071067690849304
# Contour #51 has area = 20.0 and perimeter = 17.313708305358887
# Contour #52 has area = 5.5 and perimeter = 9.071067690849304
# Contour #53 has area = 28.0 and perimeter = 20.485281229019165
# Contour #54 has area = 29.0 and perimeter = 21.656854152679443
# Contour #55 has area = 26.0 and perimeter = 19.656854152679443
# Contour #56 has area = 8.5 and perimeter = 11.071067690849304
# Contour #57 has area = 410.0 and perimeter = 75.59797930717468
# Contour #58 has area = 13.0 and perimeter = 13.656854152679443
# Contour #59 has area = 20.0 and perimeter = 17.313708305358887
# Contour #60 has area = 28.0 and perimeter = 20.485281229019165
# Contour #61 has area = 28.0 and perimeter = 21.656854152679443
# Contour #62 has area = 23.0 and perimeter = 22.485281229019165
# Contour #63 has area = 1296.0 and perimeter = 133.882248878479
# Contour #64 has area = 12019.5 and perimeter = 437.88938760757446
# Contour #65 has area = 9676.0 and perimeter = 369.0193328857422
# Contour #66 has area = 13.0 and perimeter = 13.656854152679443
# Contour #67 has area = 5.5 and perimeter = 9.071067690849304
# Contour #68 has area = 20.0 and perimeter = 17.313708305358887
# Contour #69 has area = 27.0 and perimeter = 20.485281229019165
# Contour #70 has area = 46.0 and perimeter = 40.97056245803833
# Contour #71 has area = 14.5 and perimeter = 15.071067690849304
# Contour #72 has area = 20.0 and perimeter = 17.313708305358887
# Contour #73 has area = 27.0 and perimeter = 20.485281229019165
# Contour #74 has area = 29.0 and perimeter = 21.656854152679443
# Contour #75 has area = 9.0 and perimeter = 30.14213514328003
# Contour #76 has area = 2084.0 and perimeter = 170.0243856906891
# Contour #77 has area = 12828.5 and perimeter = 418.5756847858429
# Contour #78 has area = 332926.0 and perimeter = 2306.485281229019
# Contour #79 has area = 333536.5 and perimeter = 2392.325900912285
# Contour #80 has area = 13.0 and perimeter = 13.656854152679443
# Contour #81 has area = 30.0 and perimeter = 21.656854152679443

# %%
imageCopy6 = image.copy()
for cnt in contours:
    x,y,w,h = cv2.boundingRect(cnt)
    cv2.rectangle(imageCopy6, (x,y), (x+w,y+h), (0,255,0), 4)
plt.imshow(imageCopy6[:,:,::-1]);

# %%
imageCopy7 = image.copy()
for cnt in contours:
    box = cv2.minAreaRect(cnt)
    boxPts = cv2.boxPoints(box).astype(np.int64)
    cv2.drawContours(imageCopy7, [boxPts], -1, (0,255,0), 4)
plt.imshow(imageCopy7[:,:,::-1]);

# %%
imageCopy8 = image.copy()
for cnt in contours:
    ((x,y),radius) = cv2.minEnclosingCircle(cnt)
    cv2.circle(imageCopy8, (int(x),int(y)), int(round(radius)), (0,255,0), 4)
plt.imshow(imageCopy8[:,:,::-1]);

# %%
imageCopy9 = image.copy()
for cnt in contours:
    if len(cnt) < 5:
        continue
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(imageCopy9, ellipse, (0,255,0), 4)
plt.imshow(imageCopy9[:,:,::-1]);
